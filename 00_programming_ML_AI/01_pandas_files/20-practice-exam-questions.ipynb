# %%
import numpy as np

# %%
arr = np.array([[1, 2], [3, 4]])
np.transpose(arr, (1, 0))

# %%
a = np.array([1, 2, 3])
b = np.array([4, 5, 6])
c = np.array([[7, 8], [9, 10]])
d = np.array([[11, 12], [13, 14]])


np.concatenate((c, d), axis = 1)

# %%
mat = np.array([[1, 2], [2, 3], [3, 4]])
mat.sum(axis = 1)

# %%
import pandas as pd
s = pd.Series([5, 10, 15, 20, 25])
s.pipe(lambda x: x[x > 10]).pipe(lambda x: x * 2)
